# %% [markdown]
# ## K-means clustering

# %% [markdown]
# In this exercise we explore $K$-means clustering - and we it out on the locations of the PROSTITUTION crime type. Applying a clustering method makes sense because we know from our earlier work that this crime type tends to happen in only a few locations. We'll also talk a little bit about model selection and overfitting in unsupervised models.

# %% [markdown]
# ### Exercise: $K$-means
# Visualize the prostitution data (e.g. by plotting it on a map)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geoplotlib
import numpy as np
from geoplotlib.utils import BoundingBox, DataAccessObject
from sklearn.cluster import KMeans
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
#Load data from csv to pandas
crimeData = pd.read_csv("SFPD_Incidents_-_from_1_January_2003.csv")

# %%
prostCrime = crimeData[crimeData['Category'].isin(['PROSTITUTION'])]
geoPlotData = {}
lon = [float(d) for d in prostCrime[prostCrime['Category'].isin(['PROSTITUTION'])].X.tolist()]
lat = [float(d) for d in prostCrime[prostCrime['Category'].isin(['PROSTITUTION'])].Y.tolist()]
geoPlotData['PROSTITUTION'] = {"lon": [float(d) for d in lon], "lat": [float(d) for d in lat]}

# %%
geoplotlib.inline()
print 'PROSTITUTION'
geoplotlib.kde(geoPlotData['PROSTITUTION'], bw=10, cut_below=1e-4, cmap='Blues')
north = np.mean(geoPlotData['PROSTITUTION']["lat"]) + 0.04
south = np.mean(geoPlotData['PROSTITUTION']["lat"]) - 0.07
west = np.mean(geoPlotData['PROSTITUTION']["lon"]) - 0.01
east = np.mean(geoPlotData['PROSTITUTION']["lon"]) + 0.01
bbox = BoundingBox(north = north, west = west, south = south, east = east)

geoplotlib.set_bbox(bbox)
geoplotlib.inline()
# Out:
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...%2Bv6lmBUR%0AkpCYwYAZDBjwWM6sytpd/fTqtfYnPuu8Onv37u5dWU%2Bl0yNgwAw2mEmgKRRzxB2h80IgI0sCicFM%0A92%2BtXGlEKBQCJEVc9zVEAJRB3QpvPi5c9yFQFNUmEgQQBRbjw0OXsr/F1TWUyxGUDAPlcoiEGgfL%0AsBc4PgLTshCEIVQ5homRYYgCfynH2qrF1TU8ejgCjmWRK2r4ur0LWYrVbZfXivjtxdOfemzU3fJh%0A%2BTMAQOCEaz4S6liumMfU2CiW1zeQUBNgGabm%2Bz7xYNkOpscfYn5lFelkCiQI6ra7D1zfg2WbiEYY%0AJNQ48loRvzyZAcvWfwZs7uxCN51Tf06W4wAAIpEyIhEgriiwbK/hfVzfQ2cyjoHeHgCA7TjIFzVs%0A7u5DjsVQLgfwvAAkIBB4HiOD/VjZ%2BIpUInk5T56qKmgank4/QkwSz3X/NwtLDT9jKYq6eV4%2Bmb3u%0AQ6CoGue/6qQoiqJOFYQ%2BdNMACc53kt%2BMppfwy9M5AMC7xRXEJLHtIKKml8CyLDo7EhgbGoAkXu4x%0AtiMZj%2BNf7z7i0cgQvnzbRUciUbcNCQh6u9LXcHTUXZJUFRR147oP417ziQfdtCCJIlgmCpZhocQk%0A/Pp0Dq8/LqAj0VGzvW5a1YUDUai8T2m6BkmMIXaN71vXQeB4MFEGLMMgV8zj1ZPZhsFDy3awf5hD%0AQo033ZemlzDY2w0A2D3IQhIl7B/m6gJ%2BtusgDEMYlgWB%2B764JIkiBnpFdKVTeP1xATEphriiVL%2B/%0AsvEVqkyDVFdBFPlzBw8BIKHKcD0PTJS7xKOiKIqi7gMaQKQoiroixZKOX57OgWtwgXdeJAgRiUSr%0A%2Bxzq70EmlwfLsCABgW7qiEYYBGEIURDBsVFwbG1G4UE%2Bh6dTj5BQlUYP8dN1p1PY3NnD3mGuYfAQ%0AqGS7jAz0/eQjo%2B4S23GwkzmkGVHXTDctPJmcwNtPy3AcB8l4AvuHWQwP9OPR6ENsbG1Dlb%2B/N51c%0AHHE9DyzLwnE98ByHkkFqglb3AcswyGtFPJ2aBM/VBoB29jNY3dxCTIxBjslN9%2BH6lZ/jcTbh%2Brcd%0AqLJSfW1oegkkIEioCYRhiIQq4/H4Q%2BSLWs1%2B1ja3YDsuACAMw5rv0dfZ1QhC/8KB2d7OTsyvrDX9%0AvKUoiqKoZmgAkaIo6orwHI98UUNP5%2BVlzoVhCBIE1a85jkMQlAEOKBkGXj2ZrQYXc0UNjuvCdhy4%0AngdNNxFXFMiSVLOP68axLCKRMiSheUaFTwgUms1CNWE7DkqGeepr7ePyKg1q3BC5YhEcw0BNp6HK%0AEkShUlKeTibwbW8Pml5CGIboSCTBMFEAACEEEQCmZeG///YrgMp73uLqGmKSXJMddxksx4HjOmCi%0A0VMz%2Ba7L8fshIaSahdjTmcbm7n6lFNlx4Pl%2BXZYmCQI4joNfn81Vb3vxeAoflleq5eGiKEKWBNiO%0Ai46EitEHg0f3zVfvUylh1hFXFKSTqat%2ButQRJsqhoJUutI9csYiYJF3SEVEURVH3SfS6D4CiKOqu%0AUmUFG1vf8PvbD/B8H0CltMwwrXPvc/LhCFAuY3F1DQAgCQIIIQAAJhqtyXZMJxMY6OnG%2BPAQZibG%0A8duLp9ANE7IUw9ft3fM/sUu0f5jFm4UlWkpFXcjH5VXsHhzi97cfsLlT%2Bdv2CUGuqCGTzeHf7%2Bcv%0AVPJHXR4mGsXKxleE5RCWbWF8eKgm8Ptsegq/PptDV7qj0uvw6D1NM0w4jouBnq7qtnFFwd%2BeP4Mq%0AS8gV89BNA5bjXGiBpGQY0PQS%2BrvTeDI5Acfz4BPv/E/4CsixGNY2t1AyDPz/fv83ckeZgT4h4DgG%0AJAjAsVEMD/QirxVr7ssyDMIwxP5hFkAlALm5u1vN5GQZBo7jQNNNhOXK7%2BtYcCLLcO8wS4NQ14Tn%0ABPz7/Txcr7W/S58Q7GQO8H5pGb%2B//YCdzCGYe9hDlKIoiro4moFIURTVpqJeAseylYs1lm3YjHw/%0AewCOZaHEFDAMgw9LKxAFETuZDP6Pl8/P/dgxScTT6Uksr38BAHzZ3q4GRhr1wvrRs8eP8O7TCiKI%0AwLKdawmq5Ioavu3tIVfQUC6X0dvV1VIPx%2BOfdyOGadEMxXtqJ3MAnuchCSIkQULJMPHPN%2B8QiUQh%0ACmJ12BB1/TK5LF7OTEORYyCE4N8f5pErakgn60sph/r78PrjQjW7LZ1M4L/99kvD/Y4%2BGMRQXy8c%0A14Pr%2B9ja3QPAtzxohQQBSoYOgecxNjwIgeOwtrUF1/XRk%2B489/O9KgLHQ9NN5Is6EoqCdDIBQgh%2B%0Af/sBDBNFGJQxPf4Q0Uilx2QQ%2BjWLNB2JJHYyh1jf%2BoZIJApVjtW0ujh%2BvVRKpSeqt%2BeKRQgch57O%0ANPYODqu/G594KJR0dKdon9qfQeB5CDyPNwtLGBsabJh5nStq2D88xEEuD58QJBQVQRgiJgnoSqVg%0AOw4KmgFVbl7qTlEURVE/ioBOYb416BRmirp%2Bx9M/p8aGAQDL65vwiQ%2BOrc2gO54YvLmzh52DQ3ie%0AC45lEY1G8Lfnzy7teN4vLcOyXcQVBY5r4y9zZ09r2z/M4tteBkAZr65hutvi6hoM08bwQB/SHUn8%0A693HMy88SUBg2Q4GervQnU6BY1l4vo/DfAHFUgnf9jJ49WS2YSCCutv%2B/X6%2BLkBouzbK5Qh4jr3Q%0AlHLqYkzbqllgIUEA27XwqoX3KaCSDVjQShge6G/rcQkh%2BOPjYssl6yQIkCsW0NmRgGHaiESit6a3%0AYq6YRyQShU8q/SA5lqsOWeF5DkyUQ7kcwvU8xBW1renVml7CyGA/JFEAx7J496myEGY7VjV4WDIM%0AxBUFwwM9ePdphbYJuGIkCBAElWnXkUgUQRAgJvGYmRivbvN%2BaRkHuTxUuTLYprerC4SQukBjZfiN%0ACMv2joYa0axEirpp6BRm6qahZ9UURVFtKJfDmhX7wd4uLK1/qQsgApWMueGBPgwfDf/wCUG5fLlr%0ANs%2Bmp%2BATgj8%2BzCMaae3kv7erE4f5AizbQSabu9Qeja04eaGj6Qako/5np2EZFjFJRL6oYXNnD6lE%0AErliHnFFgW5aeP54igYP7yHLdmq/dhyUyyFGBisBp88bm3RQwDXJl4oY6O6qmQbMMgwkIYb/%2Bccb%0AjA8NVod4NBNXlHMF8li2vcAxyzBIJzvARBkk1NvVTqESNKzv/6jICgpaEUP9SYw%2BGETJMLCysVkz%0AoOYsckzG7kG20nuXEMixGASOr%2BmryPPfF9Ri0tnv5dT5kSCATzz0d3dBFHjYjosv29swzAD/evce%0Ajx4%2BxNrXLYRhGU%2BnJtHTmT41c7%2B/pxtft3cw2NsDnxAc5vPoiHc03JaiKIqiABpApCiKuhBB4Gv6%0AQlVv53lYtlMz6fgypzGfxLEsREGE4zpnb3xkbnICv7/9gPWt7Z8eQDzm%2BT4WPq%2B23ID/OCCQSvAg%0AAaneTxKDa3sO1PUKwxDRox5tru8iJorVYAYAqAotz7suHMtgeKAf2YKGXDEPURAhSzH4xEdMFM4M%0AHl748bn2sqlua/ZVo%2BAhUClz5lgWQ329AIBoJArLcdoKILIMc%2BbPxbJdeL4P3bRg2S5EnvZFvCq6%0AYeDl3HR1%2BnZCVdHb1Yn9wyw2vu3g4/IKOjsqAcDjz8TTzjuKpRKCsIz%2Bnu7K38oP ...
# PROSTITUTION
# ('smallest non-zero count', 9.8168492680594421e-08)
# ('max count:', 4.2386914193370524)
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...%0AEAR1CIbKzEhZqaqqZ3p7a2Zn9%2B6fe82ura3de21sx2bWdntaVFdVZlWqyMgQlCAI7XB9fH9wwAkQ%0AIIMhyYg8j2UkCYeLA5Bwur/n/b5XebL3NAV48OgpB0ctnGKRol1gqVpFInnT9AZ99ppNvvjoQxyn%0AAEAURfzff/wL1XKZzdW1Sx6h5HUQRyGGAp999tnM8gePHtJp9zAs%2B5JGJpFIJBKJRPLuUXaKrC7X%0AaB93WVtbmXnu%2BLhNuVLGNIwX2vfID3AHA0zTpFjKrue7nR4rK40LbytESn25hqEvHsPRUYvaUnXu%0A%2BSiOaB0dMxwOWV1dZX19Y27b406bw/19FEVlaalGZ%2BDy5%2B%2B/Rwgxs56qqlRKJUrFEhXHuejLl1wB%0A4jghTSKEEKRJTBLHoKhUyiUcx8FxHMplh0KhdKnjTBLB0O3jDl2GwyGjkcdwOARFRdNUFE1HM3R0%0A3XxtYxi6Lk8P9vkfvv6SxlKNMIroD136wyH94ZDewGUwHBLFMaqqYhoGlmliGga6riOEIIpjRp5H%0AkiQUCwVW60uvdczPy3c/P%2BCrTz7i%2BsZ6vuzgoMn6%2Buoztw2CkH6/z9JSpo8lSXyy34ePabW7XFtw%0Annnb%2BGXnKfe2b3D35o1z19MBjlo9Do5abKytUCmW38gAJZLTpCLioNViqVrBcQp0un2WahUMw6Ba%0ALjNwXeIoRDeuzslI8mrQNAU/iOaWW5o%2BdzEnkUgkEolEInk5BsMRBcvELtoMBkPK5ROBzLZtet2L%0ACX7TjPwAz3VRVXVO3DNta%2B440wRBmAknQLVWxR26JHF8poBYLpfoD4YsLy0BmXDYPu7S6/dYaTS4%0AffvO3Da9fpe93X3SVLC6uspoNKJYKtB3Pe7euIHr%2Bbgjl77rIoRACEF3MKA7GLB/pFKwLapOGadY%0ARNP053pvJK%2BPJImJowiRJKRJQioSLNum4mRiYaFYpuwUME3rUsfpeS6uO2IwGDIcDhm62e%2B4pme/%0AS5phomgGpVr9jY4rijNB7I/f/o1ECPwgQFVVdF3DNi0s02S9sYJh6ljG5b6HL0rFcfj2xwcUbJvG%0AUg0AyzJx3RGlUvHM7eI4ot/vU61V0XWDIPDy554eHLHfbHHr2vXXPfw3QhzHFOxnm3b0MIr47ucH%0AbK6tSvFQcqkoqkG17NDp9fmv//1fASjYNkmSEEaZuLR31GJtpYElRcR3CkU1iEN3brldsEmnZnkk%0AEolEIpFIJK%2BGTm/InZtbHB21KJcdojhiOHCJx06jIAixrGdfc7uehz/Kbqwdx1m4TbVc5uiohV2w%0AZkTBaeFwZlunRK/bw7YLC49p2wVc18vdQZ1ul%2BV6nffu3Z1zlfUHXQ72D4njmEajkb/W0Wgyfh9N%0A06k4DhXHYQPw3CFd18XzfYIoc7K5Iw93/DoLto1TLFItFmWlzBsiSWJSIUiSBJEkiCgEst%2BbWq2C%0A4zgUSwUq5dolj1MwdF3cYf98V6Fdwta1Sx0rwFK1imkaBGGIrukYhkHBejuFwrPYWlvn4KjJf/vn%0Af%2BXW9S0%2BvneHcrlEp9PDsgz0MyYqRJpNaEzc2JZVIAhCOv0%2B3//8C9tb74p4mBAnCU7xbDF1gv7L%0Akz0Aqk7ldY9LInkm641Vlqo1hu4IdzTC9UaUCtkvchhFuN6IRzs73Nzcwn7HTmy/dtJ03mloGiZC%0ApJcwGolEIpFIJJJ3myiOaXd72LbN8XEbIQTFYpGlcRnjoD/Ass52Q4VRxGA4RMQJwDMdi7ZtM3I9%0AqlVjRqwslcsU7dnr%2Bkl55LMcQu12G1XVFgqHnueyv3%2BQlzNXqyf3u2EQYdoWI9c7vUsACiWHQilz%0ASwa%2Bx8DzGI5GeL6f7dv38Xyfo3YbyzBwSiWWazXpTHxFJEmMiGPiOM5dhZqm4zglyks1HKdEqVS8%0A9BJkPwgZDnqMRiOGwyG9/iAvl9ZNE1VVUTT1jbsKn5dSoZjfc7%2BrrK%2BsUnYcdg%2Bb7Ddb/Mff/5Zi%0Aschg4LI0diWeZlEbh6cHB3z/8y9srW%2BgXwEB%2BFWQpJlhp2A/W1/Rj9ptlmu11zwkieTiWIaJVTNZ%0ArtWI4gRD1zhoNQl7JyWuiqpc4gglr4soCjGm3KW2XSBNpYAokUgkEolE8jroD0dsrTfwfX%2Bm7Ng0%0ADFAVRn4wJ%2B5Ni3/lcgnbLnDc6eD73pmOQYBy2eHw8AghurlwuHTODatTLtHt9OYExF6vz9FRi1Kp%0AyMbG%2BkLh8PDwiG63S6OxzL17d%2Bf2HYYhJafEUbv7rLcIyy5g2QUaS3XiKGQw8hiMhnh%2BgBCCIIoI%0Aul3qlQq8G3rCGyWOwjlXYbFYoFLOehWWnBLVSu1SxyhEwmA4whsNGQyHec9CAE3Xr5yrULKYUqHI%0Anes3OTo%2B5v/47//Cf/p3X%2BP7PiPfo3jOuWvC7mGTb374ievrG%2B%2BUSzMKYwxdv1DfW90pFlldfr7%2B%0AFhLJm8IYn4CXa8ss15ZJkhhFVWQJ8zuIqmqE4ayAqKrKQmeiRCKRSCQSieTl8YOQwXBEsVhkeMqJ%0AUyk7dDu9XECM4oiR6xGGIUWnxFLhZN2y45xbcjzBti3iOL5Qf0VDNzDNkz5lg8GQZquFqevc3L6e%0Al6p6nkuhUMLzXI6P2xy325Qdh83NDUxz/p4hiiPiOMY0DDzPf/abNIVumCxVTZaqVZIkzvsmBlEk%0A%2B7Q/g2lXoSLE%2BL5Oo%2BwUcaq1KxNs4gch7qiPO8hEwr7rEQd%2BXoJ8Wb0KJa%2BOleVlKlHA9z8/4r3b%0A2/S6vWcKiL1enz9%2B%2BzdW6nWc0uX%2Bjr5qwjiiWHi2gArjEBWJ5KozERINOaPzTuMFEdPnY0NeiEkk%0AEolEIpG8VtrdPjevrTMajYjiKHchGvpJGXEcx5lwWCzOlAJPmJQcL3IsTlOtVjg6as0c5zyKpQLt%0A4y5HRy0Arm1uUqstza23t7fLUatFqVhka3MTTVNQlGxy%2BnRPxiSOMU2T3sAlTl58onq6b6JkljgK%0ASYWYKUG2LAunVMRxlvOy9csUCxe6Ct0RpGLGVagZFtY7Xt77a8QyLOI4YeB62LZ9bruEke/xf/7b%0AnyiXSjSW3j3hOIpjChfs5aoPRyOe7O1yY3PrNQ9LIpFIzkYzjDwFbBpVlaKxRCKRSCQSyesiTgTN%0A4y7LVWcm2RiyMuL2cZdisfBM1%2BCk5Pg8ARGg6JTm3I6LCIKQVquFqqpsbm0sLGNtNg85ODjAcZxc%0AOJyQpgmqrs2JmkEQYVkGvcF8gJ/k%2BZgONkmjiGQcfug4Dk61fGWCTYIwYOgOFroK9bFLVTN0StXL%0AHafkzaLrGp2ey%2BZaDYBHu/tsb23MrBPHEf/4b99gaDrrK6uXMMrXTxRFLC%2BYGFqELoTACwL6o4FM%0AYZZIJJdKHMw3sjZNI%2B%2BFKZFIJBKJRCJ59Xiej1qvgUhn0pcN3cC2LVRVfeY%2Bcsei51E6pxyuVCjg%0Aj7wzU57DKOK4dYzrjlhbW2V1dW1unVbriP39A3RdZ3V9DctYXFinKZAkydxy2y6we9h%2B5muSnPC2%0ABJv0%2BoNzXYWqqqJbhnQVSgCI45Anu01anTZH7TaGrrG1diIU/tNf/oYX%2BNzcuHaJo3y9RHGMfYEA%0AFQC94jhsra2/5iFJJBLJ%2BaiqShCGc8tt28KPEmRXaolEIpFIJJLXQ5wIDo/arC4vMRwOZ9KXi6XC%0 ...

# %% [markdown]
# Train models of $K = 2,\ldots,10$ on the prostitution data.

# %%
prostOutlier = [(x,y) for (x,y) in zip(lon,lat) if y != 90]

# %%
lonOutlier = [x[0] for x in prostOutlier]
latOutlier = [x[1] for x in prostOutlier]
meanLon = np.mean(lonOutlier)
meanLat = np.mean(latOutlier)

# %%
kmeans = []
for i in xrange(2,10,1):
    kmeans.append(KMeans(n_clusters=i, random_state=0).fit(prostOutlier))

# %% [markdown]
# Explore how the total squared error changes as a function of $K$ and identify what you think is the right number of clusers based on the knee-point in the squared error plot.

# %%
squaredErrors = []
for i in range(len(kmeans)):
    squaredErrors.append(kmeans[i].score(prostOutlier))

# %%
clusters = [i for i in range(2,10)]
plt.plot(clusters,squaredErrors)
plt.title('Total squared error as a function of number of clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Squared Error')

# %% [markdown]
# **And by the way: The fit only gets better when we add more means - why not keep adding more of them: Explain in your own words why it makes sense to stop around a knee-point.** The fit gets better on our training set, when we introduce our test set it will lead to overfitting. We therefore conclude that $K=4$ is the optimal number of clusters.

# %%
centers = []
for i in range(len(kmeans)):
    centers.append(kmeans[i].cluster_centers_.tolist())
centers
# Out:
# [[[-122.41721258127922, 37.78739426221802],
#   [-122.41924311718914, 37.76000421665213]],
#  [[-122.41582476469686, 37.761346056903406],
#   [-122.41709742374232, 37.78742454987841],
#   [-122.47811474903897, 37.73890648569841]],
#  [[-122.41708247002195, 37.78742711884176],
#   [-122.4157933283197, 37.76144681116217],
#   [-122.46632498052548, 37.718814247089576],
#   [-122.48639782848089, 37.75857230467054]],
#  [[-122.41584224261476, 37.76142569868439],
#   [-122.41876997704011, 37.78765447103969],
#   [-122.46632498052548, 37.718814247089576],
#   [-122.48639782848089, 37.75857230467054],
#   [-122.4045346858759, 37.78553068672912]],
#  [[-122.41584104423832, 37.7614223162626],
#   [-122.41734574019395, 37.78626408225128],
#   [-122.48653563661559, 37.7584929825487],
#   [-122.46632498052548, 37.718814247089576],
#   [-122.40357635664827, 37.785479856299915],
#   [-122.42168637567067, 37.790816208502285]],
#  [[-122.42168787770677, 37.790846125985354],
#   [-122.41599717453238, 37.761708702352564],
#   [-122.46896682755931, 37.71915734250212],
#   [-122.48653563661559, 37.7584929825487],
#   [-122.41735751222978, 37.786267829315676],
#   [-122.40357635664827, 37.785479856299915],
#   [-122.40427087922062, 37.727771011507734]],
#  [[-122.41601766933655, 37.76171719533092],
#   [-122.42168637567067, 37.790816208502285],
#   [-122.47519678558136, 37.7182299222815],
#   [-122.4865039991358, 37.75861009122587],
#   [-122.40357635664827, 37.785479856299915],
#   [-122.44022935778337, 37.721802186331146],
#   [-122.4173449078274, 37.78626649441759],
#   [-122.39676264547874, 37.73328054578261]],
#  [[-122.41644214627301, 37.75909447214736],
#   [-122.41615427318932, 37.78489664715682],
#   [-122.48636572534035, 37.7586892476172],
#   [-122.44419190727716, 37.72179418013964],
#   [-122.41997218381327, 37.78913409750963],
#   [-122.40337375654843, 37.78551531986636],
#   [-122.47613611774194, 37.717848167399616],
#   [-122.41564959565173, 37.76371915385393],
#   [-122.39797370159478, 37.729833240650684]]]

# %% [markdown]
# # Now we want to save the data we need (prostitution) as a csv-file:

# %%
import pandas as pd

# %%
locations1 = pd.DataFrame({ 'lon': lon, 'lat': lat })

# %%
locations1.to_csv('locations-WHATUP.csv')

# %%
locations1.to_json('locations.json')

# %%
locations1.reset_index().to_json('locations.json', orient='records')

# %%
locations1
